# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("SolutionOfBlasiusEquation.csv")

# %%
 plt.figure(figsize=(16, 10))

# %%
 plt.xticks(fontsize=14)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
 plt.yticks(fontsize=14)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.title("Solution of the Blasius Equation")
# Out:
# Text(0.5, 1.0, 'Solution of the Blasius Equation')

# %%
plt.xlabel("f'", fontsize=14)
# Out:
# Text(0.5, 0, "f'")

# %%
plt.ylabel("eta", fontsize=14)
# Out:
# Text(0, 0.5, 'eta')

# %%
plt.scatter(df["f'_literature"], df[" eta_literature"],c="blue")
plt.scatter(df["f' calculated"],df["eta_assumed"],c="green")

# %%
plt.plot(df["f'_literature"], df[" eta_literature"],c="blue")
plt.plot(df["f' calculated"],df["eta_assumed"],c="green")
